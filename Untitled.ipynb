# %%
import torch 
import torchvision
import matplotlib.pyplot as plt
import numpy as np 

from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# !pip3 install pyro-ppl==0.2.1

# %% [markdown]
# We first import the necessary dataset:

# %%
train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('mnist-data/', train=True, download=True,
                       transform=transforms.Compose([transforms.ToTensor(),])),
        batch_size=128, shuffle=True)

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('mnist-data/', train=False, transform=transforms.Compose([transforms.ToTensor(),])
                       ),
        batch_size=128, shuffle=True)

# %% [markdown]
# We take a look at the dataset:

# %%
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

images, labels = next(iter(train_loader)) 
imshow(torchvision.utils.make_grid(images))

# %%
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam
from model import model, guide 

num_iterations = 5
loss = 0

optim = Adam({"lr": 0.01})
svi = SVI(model, guide, optim, loss=Trace_ELBO())
for j in range(num_iterations):
    loss = 0
    for batch_id, data in enumerate(train_loader):
        # calculate the loss and take a gradient step
        loss += svi.step(data[0].view(-1,28*28), data[1])
    normalizer_train = len(train_loader.dataset) 
    total_epoch_loss_train = loss / normalizer_train
    print("Epoch ", j, " Loss ", total_epoch_loss_train)
# Out:
# Epoch  0  Loss  2080.795186146116
# Epoch  1  Loss  366.45694146908124
# Epoch  2  Loss  157.3896413804372
# Epoch  3  Loss  111.24041363406181
# Epoch  4  Loss  96.55677665362359

# %% [markdown]
# We first take a look at our traditional prediction apporach.

# %%
from predict import predict
predict(test_loader, number_of_samples = 10)
# Out:
# accuracy: 88 %
# {'Total images': 10000,
#  'Prediction Accuracy': 88.83,
#  'Precision': 0.8883,
#  'Recall': 0.8883,
#  'F1 Score': 0.8883}

# %% [markdown]
# We next take a look at the result from our bayesian approach.

# %%
from predict import bayeisan_predict
dict = bayeisan_predict(test_loader)

# %%
dict
# Out:
# {'Total images': 10000,
#  'Skipped': 1314,
#  'Prediction Accuracy': 95.8899378309924,
#  'Precision': 0.9285714285714286,
#  'Recall': 0.9285714285714286,
#  'F1 Score': 0.9285714285714286}

# %%
for i in [1, 10, 50, 100]: 
    dict1 = predict(test_loader, number_of_samples = i) 
    print(f"Result for predict with ", i)
    print(dict1)
    dict2 = bayeisan_predict(test_loader, number_of_samples = i)  
    print(f"Result for bayesian-predict_ with ", i) 
    print(dict2)
# Out:
# accuracy: 72 %
# Result for predict with  1
# {'Total images': 10000, 'Prediction Accuracy': 72.99, 'Precision': 0.7299, 'Recall': 0.7299, 'F1 Score': 0.7299}
# Result for bayesian-predict_ with  1
# {'Total images': 10000, 'Skipped': 0, 'Prediction Accuracy': 73.91, 'Precision': 0.75, 'Recall': 0.75, 'F1 Score': 0.75}
# accuracy: 88 %
# Result for predict with  10
# {'Total images': 10000, 'Prediction Accuracy': 88.53, 'Precision': 0.8853, 'Recall': 0.8853, 'F1 Score': 0.8852999999999999}
# Result for bayesian-predict_ with  10
# {'Total images': 10000, 'Skipped': 899, 'Prediction Accuracy': 91.9789034172069, 'Precision': 0.75, 'Recall': 0.75, 'F1 Score': 0.75}
# accuracy: 90 %
# Result for predict with  50
# {'Total images': 10000, 'Prediction Accuracy': 90.32, 'Precision': 0.9032, 'Recall': 0.9032, 'F1 Score': 0.9032}
# Result for bayesian-predict_ with  50
# ...

# %%
from predict import test_batch 
images, labels = next(iter(test_loader))
test_batch(images[:200], labels[:200], plot = True)
# Out:
# Real:  8
# Real:  5
# Real:  9
# Real:  7
# Real:  4
# Real:  3
# Real:  6
# Real:  3
# Real:  3
# Real:  3
# Real:  4
# Real:  3
# Real:  4
# Real:  5
# Real:  4
# Real:  2
# Real:  0
# Real:  2
# Real:  5
# Real:  7
# Real:  4
# Real:  4
# Real:  8
# Real:  7
# Real:  0
# Real:  5
# Real:  4
# Real:  3
# Real:  8
# Real:  3
# Real:  2
# Real:  5
# Real:  5
# Real:  9
# Real:  0
# Real:  2
# Real:  5
# Real:  7
# Real:  0
# Real:  8
# Real:  8
# Real:  7
# Real:  7
# Real:  6
# Real:  5
# Real:  7
# Real:  4
# Real:  6
# Real:  9
# Real:  7
# Real:  1
# Real:  9
# Real:  6
# Real:  6
# Real:  8
# Real:  1
# Real:  3
# Real:  7
# Real:  1
# Real:  2
# Real:  0
# Real:  1
# Real:  3
# Real:  0
# Real:  3
# Real:  7
# Real:  5
# Real:  8
# Real:  9
# Real:  8
# Real:  0
# Real:  2
# Real:  0
# Real:  8
# Real:  4
# Real:  4
# Real:  0
# Real:  7
# Real:  4
# Real:  5
# Real:  9
# Real:  9
# Real:  1
# Real:  2
# Real:  1
# Real:  4
# Real:  7
# Real:  8
# Real:  4
# Real:  4
# ...
